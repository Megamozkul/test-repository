# %%
## Часть 1 
## Уровень 1 
x=float(input())
p=float(input())
y=float(input())
a=0
while x<y:
    x=x*(1+(p/100))
    a=a+1
print(a)
# Out:
#  2
#  15
#  8
# 10

# %%
## Уровень 2
n=int(input())
a=0
b='for - частный случай цикла while'
while a<n:
    print(b)
    a+=1
# Out:
#  3
# for - частный случай цикла while
# for - частный случай цикла while
# for - частный случай цикла while

# %%
## Уровень 3
n=int(input())
a=0
while n>0:
    b=n%10
    a+=b
    n=n//10
print(a)
# Out:
#  678
# 21

# %%
## Часть 2 
## Уровень 1 
i=[1,4,1,6,'hello','a',5,'hello']
b=[]
for c in i:
    a=i.count(c)
    if a>=2:
        b.append(c)
print(list(set(b)))
# Out:
# [1, 'hello']

# %%
## Уровень 2 
from random import randint
a=[]
n=5
m= [[randint(0,100) for i in range(n)]for j in range(n)]
m
# Out:
# [[65, 41, 75, 35, 4],
#  [0, 3, 14, 57, 23],
#  [42, 53, 62, 19, 45],
#  [4, 29, 27, 87, 55],
#  [81, 72, 66, 74, 70]]

# %%
for c in m:
    d=(max(c))
    a.append(d)
print(max(a))
# Out:
# 87

# %%
## Уровень 3
d = {'name1':'id1','name2':'id2','name3':'id3'}
c={value:key 
   for key,value
   in d.items()}
print(c)
# Out:
# {'id1': 'name1', 'id2': 'name2', 'id3': 'name3'}

# %%
## Часть 3 
## Уровень 1 
def get_square(a,b,c):
    p=(a+b+c)/2
    s=(p*(p-a)*(p-b)*(p-c))**0.5
    return s
a=int(input())
b=int(input())
c=int(input())

print(get_square(a,b,c))
# Out:
#  3
#  4
#  5
# 6.0

# %%
## Уровень 2
s=  '''Было просто пасмурно, дуло с севера
А к обеду насчитал сто градаций серого.
Так всегда первого ноль девятого
То ли весь мир сошёл с ума, то ли я - того ...
На столе записка от неё смятая
Недопитый виски допиваю с матами.
Посмотрю в окно, допишу главу
Первое сентября, дворник жжёт листву.
Серым облакам наплевать на нас
Если знаешь как жить - живи
Ты хотела плыть как все - так плыви!'''
translator = str.maketrans('', '', '.,!?:;-()[]{}"""\'…')
clean_text = s.translate(translator)
def malslov(s): 
    return [c for c in (clean_text.lower()).split() if len(c) < 5]
    
print(malslov(s))
# Out:
# ['было', 'дуло', 'с', 'а', 'к', 'сто', 'так', 'ноль', 'то', 'ли', 'весь', 'мир', 'с', 'ума', 'то', 'ли', 'я', 'того', 'на', 'от', 'неё', 'с', 'в', 'окно', 'жжёт', 'на', 'нас', 'если', 'как', 'жить', 'живи', 'ты', 'как', 'все', 'так']

# %%
## Уровень 3
s=[56,9,11,2]
def chislo (s):
    a=[str(c) for c in s]
    for i in range (1,len(a)):
        a.sort(reverse=True)
    print (int(''.join(map(str,a))))
chislo (s)
# Out:
# 956211

# %%
## Часть 4 
## Уровень 1 
import json
login = 'petrov@mail.ru'
passwrd = '12345'
def register (login, passwrd):
    a ={login:passwrd} 
    with open('data.json', 'w') as f:
        json.dump(a, f)
pass

register (login, passwrd)

# %%
## Уровень 2
login = 'petrov@mail.ru'
passwrd = '12345'
def register1 (login, passwrd): 
    with open('data.json', 'w') as f:
        data1=json.load(f)
    data1.get('user1')
    res = data1.setdefault('user1', 'password1') 
    with open('data1.json', 'w') as f:
        json.dump(a, f) 
pass
register1 (login, passwrd)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[36], line 12
#      10         json.dump(a, f)
#      11 pass
# ---> 12 register1 (login, passwrd)
#
# Cell In[36], line 6, in register1(login, passwrd)
#       4 def register1 (login, passwrd):
#       5     with open('data.json', 'w') as f:
# ----> 6         data1=json.load(f)
#       7     data1.get('user1')
#       8     res = data1.setdefault('user1', 'password1')
#
# File ~\anaconda3\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
# ...

# %%
## Уровень 3
def register2 (login, passwrd):
    with open('data1.json', 'w') as f:
    data2=json.load(f)
    if passwrd in data2.values():
        print('пароль правильный')
    else:
        print('пароль неправильный')
    if login in data2.keys():
        print('логин правильный')
    else:
        print('логин неправильный') 
    with open('data2.json', 'w') as f:
        json.dump(a, f)        
pass
# Out:
#   Cell In[32], line 4
#     data2=json.load(f)
#     ^
# IndentationError: expected an indented block after 'with' statement on line 3

# %%
for i in range (1,8):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
