# %%
import pandas as pd 
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score,confusion_matrix,accuracy_score, precision_score, recall_score, f1_score,fbeta_score, roc_curve, roc_auc_score, precision_recall_curve,auc, average_precision_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression, SGDRegressor, SGDClassifier, Ridge, Lasso
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score
from sklearn.preprocessing import TargetEncoder
from sklearn.base import BaseEstimator, TransformerMixin
from category_encoders import LeaveOneOutEncoder
from sklearn.ensemble import RandomForestRegressor
from scipy import stats ##
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.inspection import permutation_importance
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.feature_selection import SelectFromModel

# %%
df2 = pd.read_csv('C:\\Users\\User\\Documents\\ДЗ\\covid_19_clean_complete.csv',index_col=4,parse_dates=True) 
df2
# Out:
#            Province/State         Country/Region        Lat       Long  \
# Date
# 2020-01-22            NaN            Afghanistan  33.939110  67.709953
# 2020-01-22            NaN                Albania  41.153300  20.168300
# 2020-01-22            NaN                Algeria  28.033900   1.659600
# 2020-01-22            NaN                Andorra  42.506300   1.521800
# 2020-01-22            NaN                 Angola -11.202700  17.873900
# ...                   ...                    ...        ...        ...
# 2020-07-27            NaN  Sao Tome and Principe   0.186400   6.613100
# 2020-07-27            NaN                  Yemen  15.552727  48.516388
# 2020-07-27            NaN                Comoros -11.645500  43.333300
# 2020-07-27            NaN             Tajikistan  38.861000  71.276100
# 2020-07-27            NaN                Lesotho -29.610000  28.233600
#
#             Confirmed  Deaths  Recovered  Active             WHO Region
# Date
# 2020-01-22          0       0          0       0  Eastern Mediterranean
# 2020-01-22          0       0          0       0                 Europe
# 2020-01-22          0       0          0       0                 Africa
# 2020-01-22          0       0          0       0                 Europe
# 2020-01-22          0       0          0       0                 Africa
# ...               ...     ...        ...     ...                    ...
# 2020-07-27        865      14        734     117                 Africa
# 2020-07-27       1691     483        833     375  Eastern Mediterranean
# 2020-07-27        354       7        328      19                 Africa
# 2020-07-27       7235      60       6028    1147                 Europe
# 2020-07-27        505      12        128     365                 Africa
#
# [49068 rows x 9 columns]

# %%
df2.isna().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
group=df2.groupby('Country/Region')['Confirmed'].sum()
df_sorted = group.sort_values( ascending=False)
df_sorted
## Возмем для обработки США
# Out:
# Country/Region
# US                       224345948
# Brazil                    89524967
# Russia                    45408411
# India                     40883464
# Spain                     27404045
#                            ...
# Saint Kitts and Nevis         1772
# Greenland                     1507
# Holy See                      1356
# Papua New Guinea              1185
# Western Sahara                 901
# Name: Confirmed, Length: 187, dtype: int64

# %%
df2
# Out:
#            Province/State         Country/Region        Lat       Long  \
# Date
# 2020-01-22            NaN            Afghanistan  33.939110  67.709953
# 2020-01-22            NaN                Albania  41.153300  20.168300
# 2020-01-22            NaN                Algeria  28.033900   1.659600
# 2020-01-22            NaN                Andorra  42.506300   1.521800
# 2020-01-22            NaN                 Angola -11.202700  17.873900
# ...                   ...                    ...        ...        ...
# 2020-07-27            NaN  Sao Tome and Principe   0.186400   6.613100
# 2020-07-27            NaN                  Yemen  15.552727  48.516388
# 2020-07-27            NaN                Comoros -11.645500  43.333300
# 2020-07-27            NaN             Tajikistan  38.861000  71.276100
# 2020-07-27            NaN                Lesotho -29.610000  28.233600
#
#             Confirmed  Deaths  Recovered  Active             WHO Region
# Date
# 2020-01-22          0       0          0       0  Eastern Mediterranean
# 2020-01-22          0       0          0       0                 Europe
# 2020-01-22          0       0          0       0                 Africa
# 2020-01-22          0       0          0       0                 Europe
# 2020-01-22          0       0          0       0                 Africa
# ...               ...     ...        ...     ...                    ...
# 2020-07-27        865      14        734     117                 Africa
# 2020-07-27       1691     483        833     375  Eastern Mediterranean
# 2020-07-27        354       7        328      19                 Africa
# 2020-07-27       7235      60       6028    1147                 Europe
# 2020-07-27        505      12        128     365                 Africa
#
# [49068 rows x 9 columns]

# %%
df2 = df2[df2['Country/Region'] == 'US']
df2
# Out:
#            Province/State Country/Region   Lat   Long  Confirmed  Deaths  \
# Date
# 2020-01-22            NaN             US  40.0 -100.0          1       0
# 2020-01-23            NaN             US  40.0 -100.0          1       0
# 2020-01-24            NaN             US  40.0 -100.0          2       0
# 2020-01-25            NaN             US  40.0 -100.0          2       0
# 2020-01-26            NaN             US  40.0 -100.0          5       0
# ...                   ...            ...   ...    ...        ...     ...
# 2020-07-23            NaN             US  40.0 -100.0    4038816  144430
# 2020-07-24            NaN             US  40.0 -100.0    4112531  145560
# 2020-07-25            NaN             US  40.0 -100.0    4178970  146465
# 2020-07-26            NaN             US  40.0 -100.0    4233923  146935
# 2020-07-27            NaN             US  40.0 -100.0    4290259  148011
#
#             Recovered   Active WHO Region
# Date
# 2020-01-22          0        1   Americas
# 2020-01-23          0        1   Americas
# 2020-01-24          0        2   Americas
# 2020-01-25          0        2   Americas
# 2020-01-26          0        5   Americas
# ...               ...      ...        ...
# 2020-07-23    1233269  2661117   Americas
# 2020-07-24    1261624  2705347   Americas
# 2020-07-25    1279414  2753091   Americas
# 2020-07-26    1297863  2789125   Americas
# 2020-07-27    1325804  2816444   Americas
#
# [188 rows x 9 columns]

# %%
df=df2[['Confirmed']]

# %%
df
# Out:
#             Confirmed
# Date
# 2020-01-22          1
# 2020-01-23          1
# 2020-01-24          2
# 2020-01-25          2
# 2020-01-26          5
# ...               ...
# 2020-07-23    4038816
# 2020-07-24    4112531
# 2020-07-25    4178970
# 2020-07-26    4233923
# 2020-07-27    4290259
#
# [188 rows x 1 columns]

# %%
print(df.index.is_monotonic_increasing)
# Out:
# True

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
## Проверка на стационарность 
from statsmodels.tsa.stattools import kpss
# Проведение теста KPSS
stat, p_value, lags, crit_values = kpss(df, regression='c')

# Вывод результатов
print(f"KPSS Statistic: {stat}")
print(f"P-value: {p_value}")
print(f"Critical Values: {crit_values}")
print(f"Lags used: {lags}")
# Out:
# KPSS Statistic: 1.8495364539611847
# P-value: 0.01
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# Lags used: 9
# C:\Users\User\AppData\Local\Temp\ipykernel_9668\3988120165.py:4: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   stat, p_value, lags, crit_values = kpss(df, regression='c')

# %%
df3=df.diff()
df3.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df4=df3.diff()
df4.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df4.isna().sum()
# Out:
# Confirmed    2
# dtype: int64

# %%
df4=df4.dropna()

# %%
## Проверка на стационарность 
from statsmodels.tsa.stattools import kpss
# Проведение теста KPSS
stat, p_value, lags, crit_values = kpss(df4, regression='c')

# Вывод результатов
print(f"KPSS Statistic: {stat}")
print(f"P-value: {p_value}")
print(f"Critical Values: {crit_values}")
print(f"Lags used: {lags}")
# Out:
# KPSS Statistic: 0.08378009888577602
# P-value: 0.1
# Critical Values: {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739}
# Lags used: 15
# C:\Users\User\AppData\Local\Temp\ipykernel_9668\633117221.py:4: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   stat, p_value, lags, crit_values = kpss(df4, regression='c')

# %% [markdown]
# ## Тест показал, что график становится стационарным после 2-ого дифференцирования

# %%
# !pip install pmdarima
from pmdarima import auto_arima
# Out:
# Requirement already satisfied: pmdarima in c:\users\user\anaconda3\lib\site-packages (2.1.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\user\anaconda3\lib\site-packages (from pmdarima) (1.5.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\user\anaconda3\lib\site-packages (from pmdarima) (3.2.5)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\user\anaconda3\lib\site-packages (from pmdarima) (2.3.5)
# Requirement already satisfied: pandas>=0.19 in c:\users\user\anaconda3\lib\site-packages (from pmdarima) (2.3.3)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\user\anaconda3\lib\site-packages (from pmdarima) (1.7.2)
# Requirement already satisfied: scipy>=1.13.0 in c:\users\user\anaconda3\lib\site-packages (from pmdarima) (1.16.3)
# Requirement already satisfied: statsmodels>=0.14.5 in c:\users\user\anaconda3\lib\site-packages (from pmdarima) (0.14.5)
# Requirement already satisfied: urllib3 in c:\users\user\anaconda3\lib\site-packages (from pmdarima) (2.5.0)
# Requirement already satisfied: setuptools!=50.0.0,>=42 in c:\users\user\anaconda3\lib\site-packages (from pmdarima) (80.9.0)
# Requirement already satisfied: packaging>=17.1 in c:\users\user\anaconda3\lib\site-packages (from pmdarima) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\user\anaconda3\lib\site-packages (from statsmodels>=0.14.5->pmdarima) (1.0.1)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

fig, axes = plt.subplots(3, 2, figsize=(14, 10))

# 1. Исходный ряд (кумулятивные случаи)
plot_acf(df['Confirmed'].dropna(), ax=axes[0,0], lags=30, title='ACF: Исходный ряд')
axes[0,1].plot(df['Confirmed'])  # для наглядности
axes[0,1].set_title('Исходный ряд')

# 2. Первая разность (прирост)
df3=df3.fillna(0)
plot_acf(df3, ax=axes[1,0], lags=30, title='ACF: Первая производная')
axes[1,1].plot(df3)
axes[1,1].set_title('Первая производная')

# 2. Вторая разность (прирост)
plot_acf(df4, ax=axes[2,0], lags=30, title='ACF: Вторая производная ')
axes[2,1].plot(df4)
axes[2,1].set_title('Вторая производнпая')
# Out:
# Text(0.5, 1.0, 'Вторая производнпая')

# %%
# Строим PACF
fig, axes = plt.subplots(3, 2, figsize=(14, 10))

# --- Исходный ряд ---
plot_pacf(df['Confirmed'].dropna(), ax=axes[0,0], lags=30, method='ywm', title='PACF: Исходный ряд')
axes[0,1].plot(df['Confirmed'].dropna(), color='black')
axes[0,1].set_title('Исходный ряд')

# --- Первая разность ---
plot_pacf(df3, ax=axes[1,0], lags=30, method='ywm', title='PACF: Первая производная')
axes[1,1].plot(df3, color='darkgreen')
axes[1,1].set_title('Первая производная: ежедневный прирост')


# 2. Вторая разность (прирост)
plot_pacf(df4, ax=axes[2,0], lags=30,method='ywm', title='PACF: Вторая производная ')
axes[2,1].plot(df4, color='red')
axes[2,1].set_title('Вторая производнпая')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Если судить что значения P и q  являются последний лаг после кторого значения не выходят за пределы доверительного интрвалов , то P=1,q=1.Т.к ряд -кумулятивный, то очевидно что тренд будет возрастать(нелинейно- видны ускорения в апреле и июле).На гравике первой производной видно,что ряд имеет недельную сеонность "ускорения заболеваний" )

# %%
## 1 . Построение модели AUTOARIMA
confirmed = df['Confirmed']
print("Подбираем параметры ARIMA")
model = auto_arima(
    confirmed,
    seasonal=False, # для COVIDа ранней  стадии — сезонности почти нет
    max_p=7, max_q=3, max_d=2,
    trace=True, #режим подробного вывода процесса подбора модели
    suppress_warnings=True, #отключение предупреждений (warnings) от библиотек нижнего уровня
    error_action='ignore', # если какая‑то комбинация (p,d,q) вызывает ошибку (например, не сходится оценка параметров), алгоритм просто пропускает её и переходит к следующей
    stepwise=True  ## Оптимальный перебор параметров
)

print(f"\n»> Лучшая модель: ARIMA{model.order}")
print(model.summary())

# 2. ПРОГНОЗ НА 30 ДНЕЙ
n_days = 30
forecast, conf_int = model.predict(n_periods=n_days, return_conf_int=True)  ##возвращать доверительные интервалы вместе с прогнозом.

last_date = confirmed.index[-1]
future_dates = pd.date_range(
    start=last_date + pd.Timedelta(days=1),
    periods=n_days,
    freq='D' ## Частота между соседними шагами
)

forecast_df = pd.DataFrame({
    'Прогноз': forecast,
    'Нижняя граница': conf_int[:, 0],
    'Верхняя граница': conf_int[:, 1]
}, index=future_dates)


# 3. ТАБЛИЦА

print("\nПрогноз на 30 дней вперёд:")
print(forecast_df.round(0).astype(int).to_string())


# 4. ГРАФИК

plt.figure(figsize=(12, 6))

# Последние 180 дней истории для наглядности
hist = confirmed.iloc[-180:]
plt.plot(hist.index, hist, color='black', linewidth=2, label='Факт')

# Прогноз
plt.plot(forecast_df.index, forecast_df['Прогноз'],
         color='red', linestyle='--', linewidth=2, label='Прогноз ARIMA')

# 95% доверительный интервал
plt.fill_between(
    forecast_df.index,
    forecast_df['Нижняя граница'],
    forecast_df['Верхняя граница'],
    color='red', alpha=0.15, label='95% дов. интервал'
)

plt.title(f'Прогноз кумулятивной заболеваемости COVID-19\nARIMA{model.order}, горизонт {n_days} дней')
plt.xlabel('Дата')
plt.ylabel('Подтверждённые случаи')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Подбираем параметры ARIMA
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0] intercept   : AIC=3477.452, Time=0.45 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=3540.385, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=3542.291, Time=0.01 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=3542.329, Time=0.01 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=3540.001, Time=0.01 sec
#  ARIMA(1,2,2)(0,0,0)[0] intercept   : AIC=3546.789, Time=0.04 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=3541.585, Time=0.07 sec
#  ARIMA(3,2,2)(0,0,0)[0] intercept   : AIC=3464.002, Time=0.07 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=3521.119, Time=0.05 sec
#  ARIMA(4,2,2)(0,0,0)[0] intercept   : AIC=3463.065, Time=0.17 sec
#  ARIMA(4,2,1)(0,0,0)[0] intercept   : AIC=3508.409, Time=0.06 sec
#  ARIMA(5,2,2)(0,0,0)[0] intercept   : AIC=3464.163, Time=0.23 sec
#  ARIMA(4,2,3)(0,0,0)[0] intercept   : AIC=3456.221, Time=0.29 sec
#  ARIMA(3,2,3)(0,0,0)[0] intercept   : AIC=3458.153, Time=0.29 sec
#  ARIMA(5,2,3)(0,0,0)[0] intercept   : AIC=3458.212, Time=0.33 sec
#  ARIMA(4,2,3)(0,0,0)[0]             : AIC=3459.576, Time=0.25 sec
#
# Best model:  ARIMA(4,2,3)(0,0,0)[0] intercept
# Total fit time: 2.408 seconds
#
# »> Лучшая модель: ARIMA(4, 2, 3)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  188
# Model:               SARIMAX(4, 2, 3)   Log Likelihood               -1719.111
# Date:                Tue, 30 Jun 2026   AIC                           3456.221
# Time:                        22:17:24   BIC                           3485.253
# Sample:                    01-22-2020   HQIC                          3467.986
#                          - 07-27-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    413.9961    334.161      1.239      0.215    -240.946    1068.939
# ar.L1         -0.0959      0.078     -1.229      0.219      -0.249       0.057
# ar.L2          0.2327      0.070      3.335      0.001       0.096       0.369
# ar.L3         -0.8065      0.073    -10.989      0.000      -0.950      -0.663
# ar.L4         -0.4175      0.076     -5.458      0.000      -0.567      -0.268
# ma.L1         -0.1685      0.086     -1.951      0.051      -0.338       0.001
# ma.L2         -0.1857      0.104     -1.790      0.074      -0.389       0.018
# ma.L3          0.8020      0.082      9.794      0.000       0.642       0.963
# sigma2      7.051e+06      0.080   8.83e+07      0.000    7.05e+06    7.05e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.13   Jarque-Bera (JB):                76.80
# Prob(Q):                              0.72   Prob(JB):                         0.00
# Heteroskedasticity (H):              28.14   Skew:                             0.66
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 4.9e+22. Standard errors may be unstable.
#
# Прогноз на 30 дней вперёд:
#             Прогноз  Нижняя граница  Верхняя граница
# 2020-07-28  4348940         4343736          4354145
# 2020-07-29  4413975         4403550          4424400
# 2020-07-30  4481844         4464994          4498693
# 2020-07-31  4548864         4524884          4572845
# 2020-08-01  4610936         4579743          4642130
# 2020-08-02  4668761         4629941          4707582
# 2020-08-03  4725757         4678938          4772576
# 2020-08-04  4786604         4730877          4842331
# 2020-08-05  4852793         4787341          4918246
# 2020-08-06  4922222         4846222          4998221
# 2020-08-07  4990237         4903328          5077146
# 2020-08-08  5053640         4955610          5151669
# 2020-08-09  5112727         5003478          5221975
# 2020-08-10  5171356         5050542          5292170
# 2020-08-11  5233749         5100832          5366666
# 2020-08-12  5301495         5155780          5447209
# 2020-08-13  5372188         5213110          5531266
# 2020-08-14  5441413         5268619          5614208
# 2020-08-15  5505991         5319352          5692629
# 2020-08-16  5566475         5365876          5767074
# 2020-08-17  5626638         5411828          5841447
# 2020-08-18  5690654         5461170          5920138
# 2020-08-19  5759882         5515167          6004596
# 2020-08-20  5831888         5571454          6092322
# 2020-08-21  5902281         5625841          6178722
# 2020-08-22  5968078         5675508          6260647
# 2020-08-23  6029936         5721143          6338730
# 2020-08-24  6091659         5766415          6416903
# 2020-08-25  6157273         5815180          6499365
# 2020-08-26  6227991         5868561          6587420

# %%
## autoarima показывает ,что лучшими параметрами ддля P,d,q будут 3,2,3 соответственно

# %%
## Уровень 2

# %%
# 1. РАЗБИЕНИЕ: последние 30 дней — тест
# ============================================================
df['New'] = df3 ## Добавляем значения производной к исходному датафрейму ->прирост заболевших каждый день
HORIZON = 30

train = df.iloc[:-HORIZON] 
test  = df.iloc[-HORIZON:] 

actual = test['Confirmed'].values ## Ревльные значения на тестовом промежутке
last_confirmed = train['Confirmed'].iloc[-1] ## Последнее значение перед прогнозом
last_date = train.index[-1]  ## Последняя дата из обучающей части
#2. Еще раз обучает ARIMY - теперь не на всех а, на тестовых данных
arima_model = auto_arima(
    train['Confirmed'],
    seasonal=False,
    max_p=7, max_q=3, max_d=2,
    trace=True,
    suppress_warnings=True,
    stepwise=True
)
print(f"\nЛучшая модель: ARIMA{arima_model.order}")
pred_arima = arima_model.predict(n_periods=HORIZON)
# 3. GRADIENT BOOSTING (на приростах)
def make_features(series):
    d = pd.DataFrame({'New': series}) 
    for lag in [1, 2, 3, 7, 14]:## ЛАги -значения прироста 1,2,3,7,14 дней назад
        d[f'lag_{lag}'] = d['New'].shift(lag) ## сдвигает значения столбца вниз на lag строк
    d['roll_mean_3'] = d['New'].shift(1).rolling(3).mean() ## Среднее за 3 дня 
    d['roll_mean_7'] = d['New'].shift(1).rolling(7).mean() ## Среднее за 7 дней 
    d['roll_std_7']  = d['New'].shift(1).rolling(7).std()  ## Стандартное отклонение за 7 дней 
    d['dayofweek'] = series.index.dayofweek                ## День недели
    d['days_from_start'] = (series.index - series.index[0]).days  ## Сколко дней прошло от начала ряда
    print(d)
    return d.dropna()

feat_train = make_features(train['New'])
X_train = feat_train.drop(columns='New')
y_train = feat_train['New']  ## Целевая переменная- прирост 

# 4.Обучение
gb = GradientBoostingRegressor(
    n_estimators=300,
    max_depth=4,
    learning_rate=0.05,
    random_state=42
)
gb.fit(X_train, y_train)

# .Рекурсивный прогноз приростов - т.к гб прогнозирует только один шаг то сначала делается прогноз за 1 день -> добавляется к истории -> прогнозируетмя день 2 с учетом уже предсказанного дня 1
history = train['New'].tolist()
pred_new = []

for i in range(1, HORIZON + 1):
    next_date = last_date + pd.Timedelta(days=i)
    h = np.array(history)
## Формирование признаков для будующего дня
    row = {
        'lag_1':  history[-1],
        'lag_2':  history[-2]  if len(history) >= 2  else history[-1],
        'lag_3':  history[-3]  if len(history) >= 3  else history[-1],
        'lag_7':  history[-7]  if len(history) >= 7  else np.mean(h),
        'lag_14': history[-14] if len(history) >= 14 else np.mean(h),
        'roll_mean_3': np.mean(h[-3:]) if len(h) >= 3 else np.mean(h),
        'roll_mean_7': np.mean(h[-7:]) if len(h) >= 7 else np.mean(h),
        'roll_std_7':  np.std(h[-7:])  if len(h) >= 7 else 0.0,
        'dayofweek': next_date.dayofweek,
        'days_from_start': (next_date - train.index[0]).days,
    }

    X_next = pd.DataFrame([row])[X_train.columns]
    p = max(0, gb.predict(X_next)[0]) ## прогноз прироста и накопление  
    pred_new.append(p)
    history.append(p)

pred_new = np.array(pred_new)
pred_boost = last_confirmed + np.cumsum(pred_new) ## перевод прироста в кумулятивный прогноз

## 5. МЕТРИКИ

# ============================================================
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1, None))) * 100

metrics = pd.DataFrame({
    'Модель': ['ARIMA', 'Gradient Boosting'],
    'MAE': [
        mean_absolute_error(actual, pred_arima),
        mean_absolute_error(actual, pred_boost)
    ],
    'RMSE': [
        np.sqrt(mean_squared_error(actual, pred_arima)),
        np.sqrt(mean_squared_error(actual, pred_boost))
    ],
    'MAPE, %': [
        mape(actual, pred_arima),
        mape(actual, pred_boost)
    ]
}).round(2)

print("\n" + "="*50)
print("СРАВНЕНИЕ НА ТЕСТЕ (последние 30 дней)")
print("="*50)
print(metrics.to_string(index=False))

# ============================================================
# 6. ГРАФИК
# ============================================================
plt.figure(figsize=(12, 6))

# История (последние 200 дней до теста)
hist = train['Confirmed'].iloc[-200:]
plt.plot(hist.index, hist, color='black', linewidth=2, label='Факт')

# Тест
plt.plot(test.index, actual, color='green', linewidth=2, marker='o', label='Факт (тест)')

# Прогнозы
plt.plot(test.index, pred_arima, color='red', linestyle='--', linewidth=2, marker='s', label=f'ARIMA{arima_model.order}')
plt.plot(test.index, pred_boost, color='blue', linestyle='-.', linewidth=2, marker='^', label='Gradient Boosting')

plt.title('Сравнение ARIMA и Gradient Boosting\nПрогноз кумулятивной заболеваемости на 30 дней')
plt.xlabel('Дата')
plt.ylabel('Подтверждённые случаи')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9668\2609539996.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['New'] = df3 ## Добавляем значения производной к исходному датафрейму ->прирост заболевших каждый день
# Performing stepwise search to minimize aic
#  ARIMA(2,2,2)(0,0,0)[0] intercept   : AIC=2830.849, Time=0.16 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=2882.128, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=2881.631, Time=0.01 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=2881.256, Time=0.01 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=2882.068, Time=0.00 sec
#  ARIMA(1,2,2)(0,0,0)[0] intercept   : AIC=2884.630, Time=0.08 sec
#  ARIMA(2,2,1)(0,0,0)[0] intercept   : AIC=2878.775, Time=0.04 sec
#  ARIMA(3,2,2)(0,0,0)[0] intercept   : AIC=2827.911, Time=0.20 sec
#  ARIMA(3,2,1)(0,0,0)[0] intercept   : AIC=2872.162, Time=0.05 sec
#  ARIMA(4,2,2)(0,0,0)[0] intercept   : AIC=2829.060, Time=0.18 sec
#  ARIMA(3,2,3)(0,0,0)[0] intercept   : AIC=2827.393, Time=0.18 sec
#  ARIMA(2,2,3)(0,0,0)[0] intercept   : AIC=2828.332, Time=0.14 sec
#  ARIMA(4,2,3)(0,0,0)[0] intercept   : AIC=2826.573, Time=0.26 sec
#  ARIMA(5,2,3)(0,0,0)[0] intercept   : AIC=2828.532, Time=0.29 sec
#  ARIMA(5,2,2)(0,0,0)[0] intercept   : AIC=2825.676, Time=0.27 sec
#  ARIMA(5,2,1)(0,0,0)[0] intercept   : AIC=2864.717, Time=0.06 sec
#  ARIMA(6,2,2)(0,0,0)[0] intercept   : AIC=2812.037, Time=0.29 sec
#  ARIMA(6,2,1)(0,0,0)[0] intercept   : AIC=2825.828, Time=0.25 sec
#  ARIMA(7,2,2)(0,0,0)[0] intercept   : AIC=2794.722, Time=0.28 sec
#  ARIMA(7,2,1)(0,0,0)[0] intercept   : AIC=2802.348, Time=0.13 sec
#  ARIMA(7,2,3)(0,0,0)[0] intercept   : AIC=2792.326, Time=0.34 sec
#  ARIMA(6,2,3)(0,0,0)[0] intercept   : AIC=2793.962, Time=0.26 sec
#  ARIMA(7,2,3)(0,0,0)[0]             : AIC=2791.140, Time=0.32 sec
#  ARIMA(6,2,3)(0,0,0)[0]             : AIC=2791.022, Time=0.30 sec
#  ARIMA(5,2,3)(0,0,0)[0]             : AIC=2830.803, Time=0.27 sec
#  ARIMA(6,2,2)(0,0,0)[0]             : AIC=2807.408, Time=0.28 sec
#  ARIMA(5,2,2)(0,0,0)[0]             : AIC=2819.908, Time=0.28 sec
#  ARIMA(7,2,2)(0,0,0)[0]             : AIC=2792.366, Time=0.32 sec
#
# Best model:  ARIMA(6,2,3)(0,0,0)[0]
# Total fit time: 5.259 seconds
#
# Лучшая модель: ARIMA(6, 2, 3)
#                 New    lag_1    lag_2    lag_3    lag_7   lag_14  \
# Date
# 2020-01-22      0.0      NaN      NaN      NaN      NaN      NaN
# 2020-01-23      0.0      0.0      NaN      NaN      NaN      NaN
# 2020-01-24      1.0      0.0      0.0      NaN      NaN      NaN
# 2020-01-25      0.0      1.0      0.0      0.0      NaN      NaN
# 2020-01-26      3.0      0.0      1.0      0.0      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...
# 2020-06-23  35188.0  30536.0  26439.0  32749.0  23705.0  18127.0
# 2020-06-24  34935.0  35188.0  30536.0  26439.0  25559.0  20794.0
# 2020-06-25  39873.0  34935.0  35188.0  30536.0  27809.0  22950.0
# 2020-06-26  45255.0  39873.0  34935.0  35188.0  31480.0  25330.0
# 2020-06-27  42705.0  45255.0  39873.0  34935.0  32749.0  25556.0
#
#              roll_mean_3   roll_mean_7   roll_std_7  dayofweek  \
# Date
# 2020-01-22           NaN           NaN          NaN          2
# 2020-01-23           NaN           NaN          NaN          3
# 2020-01-24           NaN           NaN          NaN          4
# 2020-01-25      0.333333           NaN          NaN          5
# 2020-01-26      0.333333           NaN          NaN          6
# ...                  ...           ...          ...        ...
# 2020-06-23  29908.000000  28325.285714  3347.454989          1
# 2020-06-24  30721.000000  29965.714286  3515.335343          2
# 2020-06-25  33553.000000  31305.142857  3338.205178          3
# 2020-06-26  36665.333333  33028.571429  4227.990100          4
# 2020-06-27  40021.000000  34996.428571  6154.072523          5
#
#             days_from_start
# Date
# 2020-01-22                0
# 2020-01-23                1
# 2020-01-24                2
# 2020-01-25                3
# 2020-01-26                4
# ...                     ...
# 2020-06-23              153
# 2020-06-24              154
# 2020-06-25              155
# 2020-06-26              156
# 2020-06-27              157
#
# [158 rows x 11 columns]
#
# ==================================================
# СРАВНЕНИЕ НА ТЕСТЕ (последние 30 дней)
# ==================================================
#            Модель       MAE      RMSE  MAPE, %
#             ARIMA  36244.81  48557.06     0.96
# Gradient Boosting 207729.35 268146.77     5.52

# %%
##Уровень 3

# %%
pip install prophet
# Out:
# Requirement already satisfied: prophet in c:\users\user\anaconda3\lib\site-packages (1.3.0)
# Requirement already satisfied: cmdstanpy>=1.0.4 in c:\users\user\anaconda3\lib\site-packages (from prophet) (1.3.0)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\user\anaconda3\lib\site-packages (from prophet) (2.3.5)
# Requirement already satisfied: matplotlib>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from prophet) (3.10.6)
# Requirement already satisfied: pandas>=1.0.4 in c:\users\user\anaconda3\lib\site-packages (from prophet) (2.3.3)
# Requirement already satisfied: holidays<1,>=0.25 in c:\users\user\anaconda3\lib\site-packages (from prophet) (0.99)
# Requirement already satisfied: tqdm>=4.36.1 in c:\users\user\anaconda3\lib\site-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib_resources in c:\users\user\anaconda3\lib\site-packages (from prophet) (7.1.0)
# Requirement already satisfied: python-dateutil<3,>=2.9.0.post0 in c:\users\user\anaconda3\lib\site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil<3,>=2.9.0.post0->holidays<1,>=0.25->prophet) (1.17.0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in c:\users\user\anaconda3\lib\site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib>=2.0.0->prophet) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm>=4.36.1->prophet) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from prophet import Prophet

# %%
print("\nОбучение Prophet...")

# Prophet требует колонки ds и y
prophet_df = train.reset_index()[['Date', 'Confirmed']].rename(
    columns={'Date': 'ds', 'Confirmed': 'y'}
)

prophet_model = Prophet(
    daily_seasonality=False,## СУТОЧНАЯ СЕЗОННОСТЬ
    weekly_seasonality=True,## недельная СЕЗОННОСТЬ
    yearly_seasonality=False,## годовая СЕЗОННОСТЬ
    changepoint_prior_scale=0.05,##чувствительность модели к резким изменениям тренда
    interval_width=0.95 ## Ширина доверительного интревала
)
prophet_model.fit(prophet_df)

future = prophet_model.make_future_dataframe(periods=HORIZON, include_history=False)## таблица с 30 днями (прогноз) начина с last_date

forecast_prophet = prophet_model.predict(future)
pred_prophet = forecast_prophet['yhat'].values
# Out:
# Обучение Prophet...
# 22:58:51 - cmdstanpy - INFO - Chain [1] start processing
# 22:58:51 - cmdstanpy - INFO - Chain [1] done processing

# %%
## Обновляем словаь с метриками,добавляя Prophet
metrics = pd.DataFrame({
    'Модель': ['ARIMA', 'Gradient Boosting', 'Prophet'],
    'MAE': [
        mean_absolute_error(actual, pred_arima),
        mean_absolute_error(actual, pred_boost),
        mean_absolute_error(actual, pred_prophet)
    ],
    'RMSE': [
        np.sqrt(mean_squared_error(actual, pred_arima)),
        np.sqrt(mean_squared_error(actual, pred_boost)),
        np.sqrt(mean_squared_error(actual, pred_prophet))
    ],
    'MAPE, %': [
        mape(actual, pred_arima),
        mape(actual, pred_boost),
        mape(actual, pred_prophet)
    ]
}).round(2)
print("\n" + "="*50)
print("СРАВНЕНИЕ НА ТЕСТЕ (последние 30 дней)")
print("="*50)
print(metrics.to_string(index=False))
# Out:
# ==================================================
# СРАВНЕНИЕ НА ТЕСТЕ (последние 30 дней)
# ==================================================
#            Модель       MAE      RMSE  MAPE, %
#             ARIMA  36244.81  48557.06     0.96
# Gradient Boosting 207729.35 268146.77     5.52
#           Prophet 578184.48 666469.95    16.00

# %%
hist = train['Confirmed'].iloc[-100:]
plt.plot(hist.index, hist, color='black', linewidth=2, label='Факт')

# Тест
plt.plot(test.index, actual, color='green', linewidth=2, marker='o', label='Факт (тест)')
# Модели
plt.plot(test.index, pred_arima,  color='red',    linestyle='--',  linewidth=1, marker='s', label=f'ARIMA{arima_model.order}')
plt.plot(test.index, pred_boost,  color='blue',   linestyle='-.',  linewidth=1, marker='^', label='Gradient Boosting')
plt.plot(test.index, pred_prophet, color='purple', linestyle=':',   linewidth=1, marker='d', label='Prophet')

plt.title('Сравнение: ARIMA, Gradient Boosting, Prophet\nПрогноз кумулятивной заболеваемости на 30 дней')
plt.xlabel('Дата')
plt.ylabel('Подтверждённые случаи')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
##Бэйзлайн
pred_naive =np.concatenate(([last_confirmed],actual[:-1]))

# %%
plt.figure(figsize=(12, 6))

hist = train['Confirmed'].iloc[-200:]
plt.plot(hist.index, hist, color='black', linewidth=2, label='Факт')
plt.plot(test.index, actual, color='green', linewidth=2, marker='o', label='Факт')

# Модели
plt.plot(test.index, pred_arima,  color='red',    linestyle='--',  linewidth=2, marker='s', label=f'ARIMA{arima_model.order}')
plt.plot(test.index, pred_boost,  color='blue',   linestyle='-.',  linewidth=2, marker='^', label='Gradient Boosting')
plt.plot(test.index, pred_prophet, color='purple', linestyle=':',   linewidth=2, marker='d', label='Prophet')

# Бейзлайн
plt.plot(test.index, pred_naive, color='gray', linestyle='-', alpha=0.8, linewidth=2, label='Бейзлайн решение')

plt.title('Модели vs Наивный бейзайн - прогноз на завтра- сегодняшнее число\nПрогноз кумулятивной заболеваемости на 30 дней')
plt.xlabel('Дата')
plt.ylabel('Подтверждённые случаи')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
##Сравнить результат со сглаживанием и без.
## добавил данные smooth, и перевел все выше модели в фунукции

# %%
# 4. fEAURE SELECTION

from sklearn.feature_selection import mutual_info_regression

print("ОЦЕНКА ПРИЗНАКОВ ЧЕРЕЗ ВЗАИМНУЮ ИНФОРМАЦИЮ")

feat_diag = make_features(train['New'])
X_diag = feat_diag.drop(columns='New')
y_diag = feat_diag['New']

mi = mutual_info_regression(X_diag, y_diag, random_state=42)
mi_series = pd.Series(mi, index=X_diag.columns).sort_values(ascending=False)

print("\nВзаимная информация признаков с таргетом:")
print(mi_series.round(4).to_string())

plt.figure(figsize=(10, 6))
mi_series.sort_values().plot(kind='barh', color='steelblue', edgecolor='black')
plt.title('Mutual Information с таргетом New')
plt.xlabel('Mutual Information')
plt.grid(True, alpha=0.3, axis='x')
plt.tight_layout()
plt.show()
# Out:
# ======================================================================
# ОЦЕНКА ПРИЗНАКОВ ЧЕРЕЗ ВЗАИМНУЮ ИНФОРМАЦИЮ
# ======================================================================
#                 New    lag_1    lag_2    lag_3    lag_7   lag_14  \
# Date
# 2020-01-22      0.0      NaN      NaN      NaN      NaN      NaN
# 2020-01-23      0.0      0.0      NaN      NaN      NaN      NaN
# 2020-01-24      1.0      0.0      0.0      NaN      NaN      NaN
# 2020-01-25      0.0      1.0      0.0      0.0      NaN      NaN
# 2020-01-26      3.0      0.0      1.0      0.0      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...
# 2020-06-23  35188.0  30536.0  26439.0  32749.0  23705.0  18127.0
# 2020-06-24  34935.0  35188.0  30536.0  26439.0  25559.0  20794.0
# 2020-06-25  39873.0  34935.0  35188.0  30536.0  27809.0  22950.0
# 2020-06-26  45255.0  39873.0  34935.0  35188.0  31480.0  25330.0
# 2020-06-27  42705.0  45255.0  39873.0  34935.0  32749.0  25556.0
#
#              roll_mean_3   roll_mean_7   roll_std_7  dayofweek  \
# Date
# 2020-01-22           NaN           NaN          NaN          2
# 2020-01-23           NaN           NaN          NaN          3
# 2020-01-24           NaN           NaN          NaN          4
# 2020-01-25      0.333333           NaN          NaN          5
# 2020-01-26      0.333333           NaN          NaN          6
# ...                  ...           ...          ...        ...
# 2020-06-23  29908.000000  28325.285714  3347.454989          1
# 2020-06-24  30721.000000  29965.714286  3515.335343          2
# 2020-06-25  33553.000000  31305.142857  3338.205178          3
# 2020-06-26  36665.333333  33028.571429  4227.990100          4
# 2020-06-27  40021.000000  34996.428571  6154.072523          5
#
#             days_from_start
# Date
# 2020-01-22                0
# 2020-01-23                1
# 2020-01-24                2
# 2020-01-25                3
# 2020-01-26                4
# ...                     ...
# 2020-06-23              153
# 2020-06-24              154
# 2020-06-25              155
# 2020-06-26              156
# 2020-06-27              157
#
# [158 rows x 11 columns]
#
# Взаимная информация признаков с таргетом:
# lag_1              1.3767
# roll_mean_3        1.1598
# roll_mean_7        1.0861
# lag_2              1.0754
# lag_3              0.9968
# days_from_start    0.9807
# lag_7              0.9556
# roll_std_7         0.8948
# lag_14             0.8038
# dayofweek          0.0000

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

# Кумулятивный и дневной ряды
df['New'] = df3

# Сглаживание считаем ДО split, чтобы оно было и в train, и в test
df['New_smooth'] = df['New'].rolling(window=7, min_periods=1).mean()
df['Confirmed_smooth'] = df['Confirmed'].iloc[0] + df['New_smooth'].cumsum()

# ============================================================
# 2. ПАРАМЕТРЫ + TRAIN/TEST
# ============================================================
HORIZON = 30
train = df.iloc[:-HORIZON].copy()
test  = df.iloc[-HORIZON:].copy()

actual = test['Confirmed'].values
actual_new = test['New'].values
actual_new_smooth = test['New_smooth'].values

last_confirmed = train['Confirmed'].iloc[-1]
last_confirmed_smooth = train['Confirmed_smooth'].iloc[-1]

# ============================================================
#  ARIMA (оригинал + сглаженный)
# ============================================================
def run_arima(series):
    arima_model = auto_arima(
        series, seasonal=False, max_p=7, max_q=3, max_d=2,
        trace=False, suppress_warnings=True, stepwise=True
    )
    return arima_model.predict(n_periods=HORIZON)

pred_arima        = run_arima(train['Confirmed'])
pred_arima_smooth = run_arima(train['Confirmed_smooth'])

# ============================================================
#  GRADIENT BOOSTING (оригинал + сглаженный)
# ============================================================
'''def run_boosting(target_series, last_cum):
    feat = make_features(target_series)
    X_tr = feat.drop(columns='New')
    y_tr = feat['New']

    gb = GradientBoostingRegressor(
        n_estimators=300, max_depth=4, learning_rate=0.05, random_state=42
    )
    gb.fit(X_tr, y_tr)

    history = target_series.tolist()
    preds = []
    for i in range(1, HORIZON + 1):
        next_date = last_date + pd.Timedelta(days=i)
        h = np.array(history)
        row = {
            'lag_1':  history[-1],
            'lag_2':  history[-2]  if len(history) >= 2  else history[-1],
            'lag_3':  history[-3]  if len(history) >= 3  else history[-1],
            'lag_7':  history[-7]  if len(history) >= 7  else np.mean(h),
            'lag_14': history[-14] if len(history) >= 14 else np.mean(h),
            'roll_mean_3': np.mean(h[-3:]) if len(h) >= 3 else np.mean(h),
            'roll_mean_7': np.mean(h[-7:]) if len(h) >= 7 else np.mean(h),
            'roll_std_7':  np.std(h[-7:])  if len(h) >= 7 else 0.0,
            'dayofweek': next_date.dayofweek,
            'days_from_start': (next_date - train.index[0]).days,
        }
        X_next = pd.DataFrame([row])[X_tr.columns]
        p = max(0, gb.predict(X_next)[0])
        preds.append(p)
        history.append(p)
    return last_cum + np.cumsum(np.array(preds))

pred_boost        = run_boosting(train['New'], last_confirmed)
pred_boost_smooth = run_boosting(train['New_smooth'], last_confirmed_smooth)'''
def fit_boosting(train_new):
    feat = make_features(train_new)
    X_tr = feat.drop(columns='New')
    y_tr = feat['New']

    gb = GradientBoostingRegressor(
        n_estimators=300, max_depth=4, learning_rate=0.05, random_state=42
    )
    gb.fit(X_tr, y_tr)
    return gb, X_tr.columns

def predict_boosting_walkforward(model, feature_cols, history_series, future_index, base_level, actual_future=None):
    history = history_series.tolist()
    preds_new = []
    start_date = history_series.index[0]

    for date in future_index:
        h = np.array(history)

        row = {
            'lag_1': history[-1],
            'lag_2': history[-2] if len(history) >= 2 else history[-1],
            'lag_3': history[-3] if len(history) >= 3 else history[-1],
            'lag_7': history[-7] if len(history) >= 7 else np.mean(h),
            'lag_14': history[-14] if len(history) >= 14 else np.mean(h),
            'roll_mean_3': np.mean(h[-3:]) if len(h) >= 3 else np.mean(h),
            'roll_mean_7': np.mean(h[-7:]) if len(h) >= 7 else np.mean(h),
            'roll_std_7': np.std(h[-7:]) if len(h) >= 7 else 0.0,
            'dayofweek': date.dayofweek,
            'days_from_start': (date - start_date).days,
        }

        X_next = pd.DataFrame([row])[feature_cols]
        pred_new = max(0, model.predict(X_next)[0])
        preds_new.append(pred_new)

        if actual_future is not None and date in actual_future.index:
            history.append(actual_future.loc[date])
        else:
            history.append(pred_new)

    pred_confirmed = base_level + np.cumsum(preds_new)
    return pd.Series(pred_confirmed, index=future_index)
    
gb_model, gb_cols = fit_boosting(train['New'])
gb_model_s, gb_cols_s = fit_boosting(train['New_smooth'])
## Финальные предсказания бустинга
pred_boost = predict_boosting_walkforward(
    gb_model,
    gb_cols,
    train['New'],
    test.index,
    base_level=last_confirmed,
    actual_future=test['New']
)

pred_boost_smooth = predict_boosting_walkforward(
    gb_model_s,
    gb_cols_s,
    train['New_smooth'],
    test.index,
    base_level=last_confirmed_smooth,
    actual_future=test['New_smooth'])
# ============================================================
#  PROPHET (оригинал + сглаженный)
# ============================================================
def run_prophet(series):
    df_p = series.reset_index().rename(columns={'Date': 'ds', series.name: 'y'})
    m = Prophet(
        daily_seasonality=False, weekly_seasonality=True, yearly_seasonality=False,
        changepoint_prior_scale=0.05, interval_width=0.95
    )
    m.fit(df_p)
    future = m.make_future_dataframe(periods=HORIZON, include_history=False)
    fcst = m.predict(future)
    return fcst['yhat'].values

pred_prophet        = run_prophet(train['Confirmed'])
pred_prophet_smooth = run_prophet(train['Confirmed_smooth'])
# ============================================================
#  модель Хольта-Винтерса
# ============================================================
def run_ses(series_cum):
    model = SimpleExpSmoothing(series_cum, initialization_method='estimated').fit()
    return model.forecast(HORIZON)
pred_ses        = run_ses(train['Confirmed'])
pred_ses_smooth = run_ses(train['Confirmed_smooth'])

# ============================================================
#БЕЙЗЛАЙН
# ============================================================
pred_naive =np.concatenate(([last_confirmed],actual[:-1]))

# ============================================================
#  МЕТРИКИ (все vs оригинальный факт)
# ============================================================
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1, None))) * 100

models = {
    'Baseline':      pred_naive,
    'SES':               pred_ses,
    'SES (smooth)':      pred_ses_smooth,    
    'ARIMA':                pred_arima,
    'ARIMA (smooth)':       pred_arima_smooth,
    'Boosting':             pred_boost,
    'Boosting (smooth)':    pred_boost_smooth,
    'Prophet':              pred_prophet,
    'Prophet (smooth)':     pred_prophet_smooth,
}

metrics = []
for name, pred in models.items():
    metrics.append({
        'Модель': name,
        'MAE': mean_absolute_error(actual, pred),
        'RMSE': np.sqrt(mean_squared_error(actual, pred)),
        'MAPE, %': mape(actual, pred)
    })

metrics_df = pd.DataFrame(metrics).round(2)
print("\n" + "="*70)
print("СРАВНЕНИЕ: ОРИГИНАЛ vs СГЛАЖЕННЫЙ РЯД (метрики vs факт)")
print("="*70)
print(metrics_df.to_string(index=False))

# ============================================================
#  ГРАФИК
# ============================================================
plt.figure(figsize=(14, 7))

hist = train['Confirmed'].iloc[-100:]
plt.plot(hist.index, hist, color='black', linewidth=2, label='Факт')
plt.plot(test.index, actual, color='green', linewidth=2, marker='o', label='Факт(test)')

# Оригинал — сплошные линии
plt.plot(test.index, pred_arima,      color='red',    linewidth=2, marker='s', label='ARIMA')
plt.plot(pred_boost.index, pred_boost.values, color='blue', linewidth=2, marker='^', label='Boosting')
plt.plot(test.index, pred_prophet,     color='purple', linewidth=2, marker='d', label='Prophet')
plt.plot(test.index, pred_ses,     color='orange', linewidth=2, marker='v', label='SES')
# Сглаженный — штриховые линии
plt.plot(test.index, pred_arima_smooth,  color='red',    linestyle='--', alpha=0.7, linewidth=2, label='ARIMA (smooth)')
plt.plot(pred_boost_smooth.index, pred_boost_smooth.values, color='blue', linestyle='--', alpha=0.7, linewidth=2, label='Boosting (s)')
plt.plot(test.index, pred_prophet_smooth, color='purple', linestyle='--', alpha=0.7, linewidth=2, label='Prophet (smooth)')
plt.plot(test.index, pred_ses_smooth,      color='orange', linestyle='--', alpha=0.7, linewidth=2, label='SES (s)')

# Бейзлайн
plt.plot(test.index, pred_naive, color='gray', linestyle='-', alpha=0.8, linewidth=2, label='baseline')

plt.title('Модели на оригинальном и сглаженном ряде (7-дневное среднее приростов)')
plt.xlabel('Дата')
plt.ylabel('Подтверждённые случаи')
plt.legend(ncol=2, fontsize=8)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9668\2533495087.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['New'] = df3
# C:\Users\User\AppData\Local\Temp\ipykernel_9668\2533495087.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['New_smooth'] = df['New'].rolling(window=7, min_periods=1).mean()
# C:\Users\User\AppData\Local\Temp\ipykernel_9668\2533495087.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Confirmed_smooth'] = df['Confirmed'].iloc[0] + df['New_smooth'].cumsum()
#                 New    lag_1    lag_2    lag_3    lag_7   lag_14  \
# Date
# 2020-01-22      0.0      NaN      NaN      NaN      NaN      NaN
# 2020-01-23      0.0      0.0      NaN      NaN      NaN      NaN
# 2020-01-24      1.0      0.0      0.0      NaN      NaN      NaN
# 2020-01-25      0.0      1.0      0.0      0.0      NaN      NaN
# 2020-01-26      3.0      0.0      1.0      0.0      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...
# 2020-06-23  35188.0  30536.0  26439.0  32749.0  23705.0  18127.0
# 2020-06-24  34935.0  35188.0  30536.0  26439.0  25559.0  20794.0
# 2020-06-25  39873.0  34935.0  35188.0  30536.0  27809.0  22950.0
# 2020-06-26  45255.0  39873.0  34935.0  35188.0  31480.0  25330.0
# 2020-06-27  42705.0  45255.0  39873.0  34935.0  32749.0  25556.0
#
#              roll_mean_3   roll_mean_7   roll_std_7  dayofweek  \
# Date
# 2020-01-22           NaN           NaN          NaN          2
# 2020-01-23           NaN           NaN          NaN          3
# 2020-01-24           NaN           NaN          NaN          4
# 2020-01-25      0.333333           NaN          NaN          5
# 2020-01-26      0.333333           NaN          NaN          6
# ...                  ...           ...          ...        ...
# 2020-06-23  29908.000000  28325.285714  3347.454989          1
# 2020-06-24  30721.000000  29965.714286  3515.335343          2
# 2020-06-25  33553.000000  31305.142857  3338.205178          3
# 2020-06-26  36665.333333  33028.571429  4227.990100          4
# 2020-06-27  40021.000000  34996.428571  6154.072523          5
#
#             days_from_start
# Date
# 2020-01-22                0
# 2020-01-23                1
# 2020-01-24                2
# 2020-01-25                3
# 2020-01-26                4
# ...                     ...
# 2020-06-23              153
# 2020-06-24              154
# 2020-06-25              155
# 2020-06-26              156
# 2020-06-27              157
#
# [158 rows x 11 columns]
#                      New         lag_1         lag_2         lag_3  \
# Date
# 2020-01-22      0.000000           NaN           NaN           NaN
# 2020-01-23      0.000000      0.000000           NaN           NaN
# 2020-01-24      0.333333      0.000000      0.000000           NaN
# 2020-01-25      0.250000      0.333333      0.000000      0.000000
# 2020-01-26      0.800000      0.250000      0.333333      0.000000
# ...                  ...           ...           ...           ...
# 2020-06-23  29965.714286  28325.285714  26771.571429  25826.571429
# 2020-06-24  31305.142857  29965.714286  28325.285714  26771.571429
# 2020-06-25  33028.571429  31305.142857  29965.714286  28325.285714
# 2020-06-26  34996.428571  33028.571429  31305.142857  29965.714286
# 2020-06-27  36418.714286  34996.428571  33028.571429  31305.142857
#
#                    lag_7        lag_14   roll_mean_3   roll_mean_7  \
# Date
# 2020-01-22           NaN           NaN           NaN           NaN
# 2020-01-23           NaN           NaN           NaN           NaN
# 2020-01-24           NaN           NaN           NaN           NaN
# 2020-01-25           NaN           NaN      0.111111           NaN
# 2020-01-26           NaN           NaN      0.194444           NaN
# ...                  ...           ...           ...           ...
# 2020-06-23  22545.571429  20362.571429  26974.476190  25059.244898
# 2020-06-24  23226.285714  20482.000000  28354.190476  26119.265306
# 2020-06-25  23920.428571  20710.428571  29865.380952  27273.387755
# 2020-06-26  24799.000000  20725.571429  31433.142857  28574.551020
# 2020-06-27  25826.571429  21129.000000  33110.047619  30031.326531
#
#              roll_std_7  dayofweek  days_from_start
# Date
# 2020-01-22          NaN          2                0
# 2020-01-23          NaN          3                1
# 2020-01-24          NaN          4                2
# 2020-01-25          NaN          5                3
# 2020-01-26          NaN          6                4
# ...                 ...        ...              ...
# 2020-06-23  2050.642114          1              153
# 2020-06-24  2419.372617          2              154
# 2020-06-25  2717.848040          3              155
# 2020-06-26  3009.673591          4              156
# 2020-06-27  3328.642674          5              157
#
# [158 rows x 11 columns]
# 00:11:48 - cmdstanpy - INFO - Chain [1] start processing
# 00:11:48 - cmdstanpy - INFO - Chain [1] done processing
# 00:11:48 - cmdstanpy - INFO - Chain [1] start processing
# 00:11:48 - cmdstanpy - INFO - Chain [1] done processing
# C:\Users\User\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\User\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# ======================================================================
# СРАВНЕНИЕ: ОРИГИНАЛ vs СГЛАЖЕННЫЙ РЯД (метрики vs факт)
# ======================================================================
#            Модель       MAE       RMSE  MAPE, %
#          Baseline  59333.33   60107.31     1.77
#               SES 860988.30 1013616.89    23.62
#      SES (smooth) 982089.68 1118310.55    27.31
#             ARIMA  36244.81   48557.06     0.96
#    ARIMA (smooth) 263824.79  285823.28     7.51
#          Boosting 213191.94  275330.40     5.67
# Boosting (smooth) 444033.08  503308.01    12.38
#           Prophet 578184.48  666469.95    16.00
#  Prophet (smooth) 686047.17  766022.77    19.24

# %%
#  FEATURE IMPORTANCE 

feat_fi = make_features(train['New'])
X_fi = feat_fi.drop(columns='New')
y_fi = feat_fi['New']

gb_fi = GradientBoostingRegressor(
    n_estimators=300, max_depth=4, learning_rate=0.05, random_state=42
)
gb_fi.fit(X_fi, y_fi)

importance = pd.Series(gb_fi.feature_importances_, index=X_fi.columns)
importance = importance.sort_values(ascending=True)

plt.figure(figsize=(10, 6))
importance.plot(kind='barh', color='steelblue', edgecolor='black')
plt.title('Важность признаков (Gradient Boosting)')
plt.xlabel('Importance')
plt.grid(True, alpha=0.3, axis='x')
plt.tight_layout()
plt.show()
# Out:
#                 New    lag_1    lag_2    lag_3    lag_7   lag_14  \
# Date
# 2020-01-22      0.0      NaN      NaN      NaN      NaN      NaN
# 2020-01-23      0.0      0.0      NaN      NaN      NaN      NaN
# 2020-01-24      1.0      0.0      0.0      NaN      NaN      NaN
# 2020-01-25      0.0      1.0      0.0      0.0      NaN      NaN
# 2020-01-26      3.0      0.0      1.0      0.0      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...
# 2020-06-23  35188.0  30536.0  26439.0  32749.0  23705.0  18127.0
# 2020-06-24  34935.0  35188.0  30536.0  26439.0  25559.0  20794.0
# 2020-06-25  39873.0  34935.0  35188.0  30536.0  27809.0  22950.0
# 2020-06-26  45255.0  39873.0  34935.0  35188.0  31480.0  25330.0
# 2020-06-27  42705.0  45255.0  39873.0  34935.0  32749.0  25556.0
#
#              roll_mean_3   roll_mean_7   roll_std_7  dayofweek  \
# Date
# 2020-01-22           NaN           NaN          NaN          2
# 2020-01-23           NaN           NaN          NaN          3
# 2020-01-24           NaN           NaN          NaN          4
# 2020-01-25      0.333333           NaN          NaN          5
# 2020-01-26      0.333333           NaN          NaN          6
# ...                  ...           ...          ...        ...
# 2020-06-23  29908.000000  28325.285714  3347.454989          1
# 2020-06-24  30721.000000  29965.714286  3515.335343          2
# 2020-06-25  33553.000000  31305.142857  3338.205178          3
# 2020-06-26  36665.333333  33028.571429  4227.990100          4
# 2020-06-27  40021.000000  34996.428571  6154.072523          5
#
#             days_from_start
# Date
# 2020-01-22                0
# 2020-01-23                1
# 2020-01-24                2
# 2020-01-25                3
# 2020-01-26                4
# ...                     ...
# 2020-06-23              153
# 2020-06-24              154
# 2020-06-25              155
# 2020-06-26              156
# 2020-06-27              157
#
# [158 rows x 11 columns]

# %%
# Кросс -валидация (ARIMA + Boosting)
# ============================================================
def rolling_cv(model_type, series_cum, series_new, n_splits=5, horizon=30):
    """
    model_type: 'arima' или 'boosting'
    series_cum: pd.Series Confirmed
    series_new: pd.Series New
    """
    N = len(series_cum)
    min_train = N // 2 ## Минимальная длина обучения - не меньше половины данных , потому что в началале заболеваемость близка к нулю
    test_starts = np.linspace(min_train, N - horizon, n_splits, dtype=int) ## 5 точек равномерно распределенных между  между min train  и  horizon

    records = []
    for start in test_starts:
        tr_cum = series_cum.iloc[:start] ## все данные от начала до дня start-1
        tr_new = series_new.iloc[:start] ## тоже но для приростов (для бустинга)
        te_cum = series_cum.iloc[start:start+horizon].values ## реальные значения на 30 днй с которыми сравниваем прогноз

        if model_type == 'arima':
            pred = run_arima(tr_cum)
        elif model_type == 'boosting':
            pred = run_boosting(tr_new, tr_cum.iloc[-1])
        else:
            raise ValueError("model_type must be 'arima' or 'boosting'")

        mae = mean_absolute_error(te_cum, pred)
        rmse = np.sqrt(mean_squared_error(te_cum, pred))
        mape_val = np.mean(np.abs((te_cum - pred) / np.clip(te_cum, 1, None))) * 100

        records.append({
            'test_start': series_cum.index[start].strftime('%Y-%m-%d'),
            'MAE': mae,
            'RMSE': rmse,
            'MAPE_%': mape_val
        })

    return pd.DataFrame(records)

# --- Запуск CV ---
print("="*70)
print("CROSS-VALIDATION (5 folds, horizon=30)")
print("="*70)

cv_arima = rolling_cv('arima', df['Confirmed'], df['New'], n_splits=5, horizon=HORIZON)
cv_boost = rolling_cv('boosting', df['Confirmed'], df['New'], n_splits=5, horizon=HORIZON)

print("\n--- ARIMA ---")
print(cv_arima.round(2).to_string(index=False))
print(f"\nСреднее CV: MAE={cv_arima['MAE'].mean():.2f}, RMSE={cv_arima['RMSE'].mean():.2f}, MAPE={cv_arima['MAPE_%'].mean():.2f}")

print("\n--- Gradient Boosting ---")
print(cv_boost.round(2).to_string(index=False))
print(f"\nСреднее CV: MAE={cv_boost['MAE'].mean():.2f}, RMSE={cv_boost['RMSE'].mean():.2f}, MAPE={cv_boost['MAPE_%'].mean():.2f}")

# ============================================================
#  ФИНАЛЬНЫЕ ПРЕДСКАЗАНИЯ (на последние 30 дней)
# ============================================================
pred_arima        = run_arima(train['Confirmed'])
pred_arima_smooth = run_arima(train['Confirmed_smooth'])

pred_boost        = run_boosting(train['New'], last_confirmed)
pred_boost_smooth = run_boosting(train['New_smooth'], last_confirmed_smooth)

pred_prophet        = run_prophet(train['Confirmed'])
pred_prophet_smooth = run_prophet(train['Confirmed_smooth'])

pred_ses        = run_ses(train['Confirmed'])
pred_ses_smooth = run_ses(train['Confirmed_smooth'])
pred_naive =np.concatenate(([last_confirmed],actual[:-1]))

# ============================================================
# МЕТРИКИ 
# ============================================================
def mape(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1, None))) * 100

models = {
    'baseline':      pred_naive,
    'SES':               pred_ses,
    'SES (smooth)':      pred_ses_smooth,
    'ARIMA':             pred_arima,
    'ARIMA (smooth)':    pred_arima_smooth,
    'Boosting':          pred_boost,
    'Boosting (smooth)': pred_boost_smooth,
    'Prophet':           pred_prophet,
    'Prophet (smooth)':  pred_prophet_smooth,
}

metrics = []
for name, pred in models.items():
    metrics.append({
        'Модель': name,
        'MAE': mean_absolute_error(actual, pred),
        'RMSE': np.sqrt(mean_squared_error(actual, pred)),
        'MAPE_%': mape(actual, pred)
    })

print("\n" + "="*70)
print(" МЕТРИКИ (последние 30 дней)")
print("="*70)
print(pd.DataFrame(metrics).round(2).to_string(index=False))
# Out:
# ======================================================================
# CROSS-VALIDATION (5 folds, horizon=30)
# ======================================================================
#                 New    lag_1    lag_2    lag_3    lag_7   lag_14  \
# Date
# 2020-01-22      0.0      NaN      NaN      NaN      NaN      NaN
# 2020-01-23      0.0      0.0      NaN      NaN      NaN      NaN
# 2020-01-24      1.0      0.0      0.0      NaN      NaN      NaN
# 2020-01-25      0.0      1.0      0.0      0.0      NaN      NaN
# 2020-01-26      3.0      0.0      1.0      0.0      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...
# 2020-04-20  27341.0  26038.0  28341.0  32724.0  25291.0  29642.0
# 2020-04-21  25602.0  27341.0  26038.0  28341.0  27065.0  30777.0
# 2020-04-22  28104.0  25602.0  27341.0  26038.0  29096.0  31694.0
# 2020-04-23  34195.0  28104.0  25602.0  27341.0  31298.0  34756.0
# 2020-04-24  36291.0  34195.0  28104.0  25602.0  32724.0  33501.0
#
#              roll_mean_3   roll_mean_7   roll_std_7  dayofweek  \
# Date
# 2020-01-22           NaN           NaN          NaN          2
# 2020-01-23           NaN           NaN          NaN          3
# 2020-01-24           NaN           NaN          NaN          4
# 2020-01-25      0.333333           NaN          NaN          5
# 2020-01-26      0.333333           NaN          NaN          6
# ...                  ...           ...          ...        ...
# 2020-04-20  29034.333333  28550.428571  2721.887388          0
# 2020-04-21  27240.000000  28843.285714  2404.527377          1
# 2020-04-22  26327.000000  28634.285714  2637.182127          2
# 2020-04-23  27015.666667  28492.571429  2634.888350          3
# 2020-04-24  29300.333333  28906.428571  3294.038497          4
#
#             days_from_start
# Date
# 2020-01-22                0
# 2020-01-23                1
# 2020-01-24                2
# 2020-01-25                3
# 2020-01-26                4
# ...                     ...
# 2020-04-20               89
# 2020-04-21               90
# 2020-04-22               91
# 2020-04-23               92
# 2020-04-24               93
#
# [94 rows x 11 columns]
#                 New    lag_1    lag_2    lag_3    lag_7   lag_14  \
# Date
# 2020-01-22      0.0      NaN      NaN      NaN      NaN      NaN
# 2020-01-23      0.0      0.0      NaN      NaN      NaN      NaN
# 2020-01-24      1.0      0.0      0.0      NaN      NaN      NaN
# 2020-01-25      0.0      1.0      0.0      0.0      NaN      NaN
# 2020-01-26      3.0      0.0      1.0      0.0      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...
# 2020-05-06  25256.0  24185.0  22475.0  25587.0  27520.0  28104.0
# 2020-05-07  27882.0  25256.0  24185.0  22475.0  29629.0  34195.0
# 2020-05-08  27178.0  27882.0  25256.0  24185.0  34162.0  36291.0
# 2020-05-09  25733.0  27178.0  27882.0  25256.0  29195.0  32921.0
# 2020-05-10  19764.0  25733.0  27178.0  27882.0  25587.0  27689.0
#
#              roll_mean_3   roll_mean_7   roll_std_7  dayofweek  \
# Date
# 2020-01-22           NaN           NaN          NaN          2
# 2020-01-23           NaN           NaN          NaN          3
# 2020-01-24           NaN           NaN          NaN          4
# 2020-01-25      0.333333           NaN          NaN          5
# 2020-01-26      0.333333           NaN          NaN          6
# ...                  ...           ...          ...        ...
# 2020-05-06  24082.333333  27536.142857  3908.933888          2
# 2020-05-07  23972.000000  27212.714286  4003.022471          3
# 2020-05-08  25774.333333  26963.142857  3879.833305          4
# 2020-05-09  26772.000000  25965.428571  2293.949350          5
# 2020-05-10  26931.000000  25470.857143  1802.077822          6
#
#             days_from_start
# Date
# 2020-01-22                0
# 2020-01-23                1
# 2020-01-24                2
# 2020-01-25                3
# 2020-01-26                4
# ...                     ...
# 2020-05-06              105
# 2020-05-07              106
# 2020-05-08              107
# 2020-05-09              108
# 2020-05-10              109
#
# [110 rows x 11 columns]
#                 New    lag_1    lag_2    lag_3    lag_7   lag_14  \
# Date
# 2020-01-22      0.0      NaN      NaN      NaN      NaN      NaN
# 2020-01-23      0.0      0.0      NaN      NaN      NaN      NaN
# 2020-01-24      1.0      0.0      0.0      NaN      NaN      NaN
# 2020-01-25      0.0      1.0      0.0      0.0      NaN      NaN
# 2020-01-26      3.0      0.0      1.0      0.0      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...
# 2020-05-22  24141.0  25355.0  23807.0  20449.0  25300.0  27178.0
# 2020-05-23  21823.0  24141.0  25355.0  23807.0  25101.0  25733.0
# 2020-05-24  20813.0  21823.0  24141.0  25355.0  19004.0  19764.0
# 2020-05-25  18991.0  20813.0  21823.0  24141.0  21769.0  18878.0
# 2020-05-26  18883.0  18991.0  20813.0  21823.0  20449.0  22190.0
#
#              roll_mean_3   roll_mean_7   roll_std_7  dayofweek  \
# Date
# 2020-01-22           NaN           NaN          NaN          2
# 2020-01-23           NaN           NaN          NaN          3
# 2020-01-24           NaN           NaN          NaN          4
# 2020-01-25      0.333333           NaN          NaN          5
# 2020-01-26      0.333333           NaN          NaN          6
# ...                  ...           ...          ...        ...
# 2020-05-22  23203.666667  22969.285714  2578.302071          4
# 2020-05-23  24434.333333  22803.714286  2437.028157          5
# 2020-05-24  23773.000000  22335.428571  2227.998942          6
# 2020-05-25  22259.000000  22593.857143  1850.033822          0
# 2020-05-26  20542.333333  22197.000000  2299.763466          1
#
#             days_from_start
# Date
# 2020-01-22                0
# 2020-01-23                1
# 2020-01-24                2
# 2020-01-25                3
# 2020-01-26                4
# ...                     ...
# 2020-05-22              121
# 2020-05-23              122
# 2020-05-24              123
# 2020-05-25              124
# 2020-05-26              125
#
# [126 rows x 11 columns]
#                 New    lag_1    lag_2    lag_3    lag_7   lag_14  \
# Date
# 2020-01-22      0.0      NaN      NaN      NaN      NaN      NaN
# 2020-01-23      0.0      0.0      NaN      NaN      NaN      NaN
# 2020-01-24      1.0      0.0      0.0      NaN      NaN      NaN
# 2020-01-25      0.0      1.0      0.0      0.0      NaN      NaN
# 2020-01-26      3.0      0.0      1.0      0.0      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...
# 2020-06-07  17731.0  22732.0  25224.0  21351.0  19910.0  20813.0
# 2020-06-08  17415.0  17731.0  22732.0  25224.0  17355.0  18991.0
# 2020-06-09  18127.0  17415.0  17731.0  22732.0  20895.0  18883.0
# 2020-06-10  20794.0  18127.0  17415.0  17731.0  19958.0  18282.0
# 2020-06-11  22950.0  20794.0  18127.0  17415.0  21351.0  22815.0
#
#              roll_mean_3   roll_mean_7   roll_std_7  dayofweek  \
# Date
# 2020-01-22           NaN           NaN          NaN          2
# 2020-01-23           NaN           NaN          NaN          3
# 2020-01-24           NaN           NaN          NaN          4
# 2020-01-25      0.333333           NaN          NaN          5
# 2020-01-26      0.333333           NaN          NaN          6
# ...                  ...           ...          ...        ...
# 2020-06-07  23102.333333  21060.714286  2466.789797          6
# 2020-06-08  21895.666667  20749.428571  2756.654788          0
# 2020-06-09  19292.666667  20758.000000  2744.407283          1
# 2020-06-10  17757.666667  20362.571429  2915.460905          2
# 2020-06-11  18778.666667  20482.000000  2913.248016          3
#
#             days_from_start
# Date
# 2020-01-22                0
# 2020-01-23                1
# 2020-01-24                2
# 2020-01-25                3
# 2020-01-26                4
# ...                     ...
# 2020-06-07              137
# 2020-06-08              138
# 2020-06-09              139
# 2020-06-10              140
# 2020-06-11              141
#
# [142 rows x 11 columns]
#                 New    lag_1    lag_2    lag_3    lag_7   lag_14  \
# Date
# 2020-01-22      0.0      NaN      NaN      NaN      NaN      NaN
# 2020-01-23      0.0      0.0      NaN      NaN      NaN      NaN
# 2020-01-24      1.0      0.0      0.0      NaN      NaN      NaN
# 2020-01-25      0.0      1.0      0.0      0.0      NaN      NaN
# 2020-01-26      3.0      0.0      1.0      0.0      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...
# 2020-06-23  35188.0  30536.0  26439.0  32749.0  23705.0  18127.0
# 2020-06-24  34935.0  35188.0  30536.0  26439.0  25559.0  20794.0
# 2020-06-25  39873.0  34935.0  35188.0  30536.0  27809.0  22950.0
# 2020-06-26  45255.0  39873.0  34935.0  35188.0  31480.0  25330.0
# 2020-06-27  42705.0  45255.0  39873.0  34935.0  32749.0  25556.0
#
#              roll_mean_3   roll_mean_7   roll_std_7  dayofweek  \
# Date
# 2020-01-22           NaN           NaN          NaN          2
# 2020-01-23           NaN           NaN          NaN          3
# 2020-01-24           NaN           NaN          NaN          4
# 2020-01-25      0.333333           NaN          NaN          5
# 2020-01-26      0.333333           NaN          NaN          6
# ...                  ...           ...          ...        ...
# 2020-06-23  29908.000000  28325.285714  3347.454989          1
# 2020-06-24  30721.000000  29965.714286  3515.335343          2
# 2020-06-25  33553.000000  31305.142857  3338.205178          3
# 2020-06-26  36665.333333  33028.571429  4227.990100          4
# 2020-06-27  40021.000000  34996.428571  6154.072523          5
#
#             days_from_start
# Date
# 2020-01-22                0
# 2020-01-23                1
# 2020-01-24                2
# 2020-01-25                3
# 2020-01-26                4
# ...                     ...
# 2020-06-23              153
# 2020-06-24              154
# 2020-06-25              155
# 2020-06-26              156
# 2020-06-27              157
#
# [158 rows x 11 columns]
#
# --- ARIMA ---
# test_start       MAE      RMSE  MAPE_%
# 2020-04-25 232608.58 284294.78   16.18
# 2020-05-11  17536.08  18410.51    1.03
# 2020-05-27  10839.98  14156.03    0.51
# 2020-06-12 194474.76 266717.25    6.83
# 2020-06-28  36244.81  48557.06    0.96
#
# Среднее CV: MAE=98340.84, RMSE=126427.13, MAPE=5.10
#
# --- Gradient Boosting ---
# test_start       MAE      RMSE  MAPE_%
# 2020-04-25  74048.32  93663.20    5.10
# 2020-05-11  17031.33  20440.59    0.96
# 2020-05-27  14149.51  26081.11    0.63
# 2020-06-12 211108.28 284515.12    7.45
# 2020-06-28 207729.35 268146.77    5.52
#
# Среднее CV: MAE=104813.36, RMSE=138569.36, MAPE=3.93
#                 New    lag_1    lag_2    lag_3    lag_7   lag_14  \
# Date
# 2020-01-22      0.0      NaN      NaN      NaN      NaN      NaN
# 2020-01-23      0.0      0.0      NaN      NaN      NaN      NaN
# 2020-01-24      1.0      0.0      0.0      NaN      NaN      NaN
# 2020-01-25      0.0      1.0      0.0      0.0      NaN      NaN
# 2020-01-26      3.0      0.0      1.0      0.0      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...
# 2020-06-23  35188.0  30536.0  26439.0  32749.0  23705.0  18127.0
# 2020-06-24  34935.0  35188.0  30536.0  26439.0  25559.0  20794.0
# 2020-06-25  39873.0  34935.0  35188.0  30536.0  27809.0  22950.0
# 2020-06-26  45255.0  39873.0  34935.0  35188.0  31480.0  25330.0
# 2020-06-27  42705.0  45255.0  39873.0  34935.0  32749.0  25556.0
#
#              roll_mean_3   roll_mean_7   roll_std_7  dayofweek  \
# Date
# 2020-01-22           NaN           NaN          NaN          2
# 2020-01-23           NaN           NaN          NaN          3
# 2020-01-24           NaN           NaN          NaN          4
# 2020-01-25      0.333333           NaN          NaN          5
# 2020-01-26      0.333333           NaN          NaN          6
# ...                  ...           ...          ...        ...
# 2020-06-23  29908.000000  28325.285714  3347.454989          1
# 2020-06-24  30721.000000  29965.714286  3515.335343          2
# 2020-06-25  33553.000000  31305.142857  3338.205178          3
# 2020-06-26  36665.333333  33028.571429  4227.990100          4
# 2020-06-27  40021.000000  34996.428571  6154.072523          5
#
#             days_from_start
# Date
# 2020-01-22                0
# 2020-01-23                1
# 2020-01-24                2
# 2020-01-25                3
# 2020-01-26                4
# ...                     ...
# 2020-06-23              153
# 2020-06-24              154
# 2020-06-25              155
# 2020-06-26              156
# 2020-06-27              157
#
# [158 rows x 11 columns]
#                      New         lag_1         lag_2         lag_3  \
# Date
# 2020-01-22      0.000000           NaN           NaN           NaN
# 2020-01-23      0.000000      0.000000           NaN           NaN
# 2020-01-24      0.333333      0.000000      0.000000           NaN
# 2020-01-25      0.250000      0.333333      0.000000      0.000000
# 2020-01-26      0.800000      0.250000      0.333333      0.000000
# ...                  ...           ...           ...           ...
# 2020-06-23  29965.714286  28325.285714  26771.571429  25826.571429
# 2020-06-24  31305.142857  29965.714286  28325.285714  26771.571429
# 2020-06-25  33028.571429  31305.142857  29965.714286  28325.285714
# 2020-06-26  34996.428571  33028.571429  31305.142857  29965.714286
# 2020-06-27  36418.714286  34996.428571  33028.571429  31305.142857
#
#                    lag_7        lag_14   roll_mean_3   roll_mean_7  \
# Date
# 2020-01-22           NaN           NaN           NaN           NaN
# 2020-01-23           NaN           NaN           NaN           NaN
# 2020-01-24           NaN           NaN           NaN           NaN
# 2020-01-25           NaN           NaN      0.111111           NaN
# 2020-01-26           NaN           NaN      0.194444           NaN
# ...                  ...           ...           ...           ...
# 2020-06-23  22545.571429  20362.571429  26974.476190  25059.244898
# 2020-06-24  23226.285714  20482.000000  28354.190476  26119.265306
# 2020-06-25  23920.428571  20710.428571  29865.380952  27273.387755
# 2020-06-26  24799.000000  20725.571429  31433.142857  28574.551020
# 2020-06-27  25826.571429  21129.000000  33110.047619  30031.326531
#
#              roll_std_7  dayofweek  days_from_start
# Date
# 2020-01-22          NaN          2                0
# 2020-01-23          NaN          3                1
# 2020-01-24          NaN          4                2
# 2020-01-25          NaN          5                3
# 2020-01-26          NaN          6                4
# ...                 ...        ...              ...
# 2020-06-23  2050.642114          1              153
# 2020-06-24  2419.372617          2              154
# 2020-06-25  2717.848040          3              155
# 2020-06-26  3009.673591          4              156
# 2020-06-27  3328.642674          5              157
#
# [158 rows x 11 columns]
# 22:59:19 - cmdstanpy - INFO - Chain [1] start processing
# 22:59:19 - cmdstanpy - INFO - Chain [1] done processing
# 22:59:19 - cmdstanpy - INFO - Chain [1] start processing
# 22:59:19 - cmdstanpy - INFO - Chain [1] done processing
# ======================================================================
#  МЕТРИКИ (последние 30 дней)
# ======================================================================
#            Модель       MAE       RMSE  MAPE_%
#          baseline  59333.33   60107.31    1.77
#               SES 860988.30 1013616.89   23.62
#      SES (smooth) 982089.68 1118310.55   27.31
#             ARIMA  36244.81   48557.06    0.96
#    ARIMA (smooth) 263824.79  285823.28    7.51
#          Boosting 207729.35  268146.77    5.52
# Boosting (smooth) 460334.12  522556.76   12.83
#           Prophet 578184.48  666469.95   16.00
#  Prophet (smooth) 686047.17  766022.77   19.24
# C:\Users\User\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# C:\Users\User\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)

# %%
#  ГРАФИК
# ============================================================
plt.figure(figsize=(14, 7))

hist = train['Confirmed'].iloc[-60:]
plt.plot(hist.index, hist, color='black', linewidth=2, label='История')
plt.plot(test.index, actual, color='green', linewidth=2, marker='o', label='Факт')

plt.plot(test.index, pred_arima,  color='red',    linewidth=2, marker='s', label='ARIMA')
plt.plot(test.index, pred_boost,  color='blue',   linewidth=2, marker='^', label='Boosting')
plt.plot(test.index, pred_prophet, color='purple', linewidth=2, marker='d', label='Prophet')
plt.plot(test.index, pred_ses,     color='orange', linewidth=2, marker='v', label='SES')

plt.plot(test.index, pred_arima_smooth,   color='red',    linestyle='--', alpha=0.7, linewidth=2, label='ARIMA (s)')
plt.plot(test.index, pred_boost_smooth,   color='blue',   linestyle='--', alpha=0.7, linewidth=2, label='Boosting (s)')
plt.plot(test.index, pred_prophet_smooth,  color='purple', linestyle='--', alpha=0.7, linewidth=2, label='Prophet (s)')
plt.plot(test.index, pred_ses_smooth,      color='orange', linestyle='--', alpha=0.7, linewidth=2, label='SES (s)')
plt.plot(test.index, pred_naive, color='gray', linestyle='-', alpha=0.8, linewidth=2, label='Naive')

plt.title('Hold-out: модели на оригинальном и сглаженном ряде')
plt.xlabel('Дата')
plt.ylabel('Подтверждённые случаи')
plt.legend(ncol=2, fontsize=8)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## В итоге получилось, что единственная модель которая прогнозирует  заболеваемость лучше бэйзлайна- модель AUto-Arima  (это видно визуально на графике и по метрикам MAPE)
# ## Сглаживание не дало улучшения прогноза модели ,  что логично т.к исходный график безсильных скачков

# %%
from scipy import stats
from statsmodels.graphics.gofplots import qqplot
from statsmodels.stats.diagnostic import acorr_ljungbox
import warnings

# %%
# 9. АНАЛИЗ ОСТАТКОВ (нормальность )
# ============================================================
residuals = {
    'ARIMA':    actual - pred_arima,
    'Boosting': actual - pred_boost,
    'Prophet':  actual - pred_prophet,
}

print("\n" + "="*70)
print("ТЕСТЫ НА НОРМАЛЬНОСТЬ ")
print("="*70)
print(f"{'Модель':<12} {'Шапиро p':<10} {'Д-Агостино p':<14}  {'Нормальность':<14} ")
print("-" * 70)

fig, axes = plt.subplots(3, 3, figsize=(15, 12))

for i, (name, res) in enumerate(residuals.items()):
    # --- Тесты ---
    sh_stat, sh_p = stats.shapiro(res) ##Тест Шапиро-Уилка
    dag_stat, dag_p = stats.normaltest(res)##Критерий Д'Агостино-Пирсона. Комбинирует оценку асимметрии и эксцесса

    normality = "Остатки распределены нормально" if sh_p > 0.05 else "НЕТ"

    print(f"{name:<12} {sh_p:<10.4f} {dag_p:<14.4f} {normality:<14}")

    # --- График 1: динамика остатков ---
    ax1 = axes[i, 0]
    ax1.plot(test.index, res, marker='o', color='black', linestyle='-')
    ax1.axhline(0, color='red', linestyle='--')
    ax1.set_title(f'{name}: остатки vs время')
    ax1.grid(True, alpha=0.3)

    # --- График 2: гистограмма + KDE + нормальная кривая ---
    ax2 = axes[i, 1]
    ax2.hist(res, bins=8, density=True, alpha=0.6, color='steelblue', edgecolor='black')
    kde = stats.gaussian_kde(res)
    x_range = np.linspace(res.min(), res.max(), 100)
    ax2.plot(x_range, kde(x_range), color='blue', lw=2, label='KDE')
    mu, std = stats.norm.fit(res)
    ax2.plot(x_range, stats.norm.pdf(x_range, mu, std), color='red', lw=2, linestyle='--', label='Normal fit')
    ax2.set_title(f'{name}: распределение')
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    # --- График 3: Q-Q plot ---
    ax3 = axes[i, 2]
    qqplot(res, line='s', ax=ax3)
    ax3.set_title(f'{name}: Q-Q plot')

plt.tight_layout()
plt.show()
# Out:
# ======================================================================
# ТЕСТЫ НА НОРМАЛЬНОСТЬ
# ======================================================================
# Модель       Шапиро p   Д-Агостино p    Нормальность
# ----------------------------------------------------------------------
# ARIMA        0.0013     0.0000         НЕТ
# Boosting     0.0120     0.0223         НЕТ
# Prophet      0.0813     0.0283         Остатки распределены нормально

# %% [markdown]
# ## Гипотеза, что остатки Для моделей ARIMA и бустинга распределены нормально не подтвердилась -> интервалы +-2сигма будут ложными
# ## На графике остатки-время ошибки со временем растут , но .т.к имеем дело с кумулятивным рядом думаю логично.(Нет смысла говорить о гетероскедастичности)
# ## На гистограме KDE синия линия мало напоминает нормальное распределение,что также опровергает гипотезу
# ## На Q-Q plot  диаграмме крывые выглядят S-образно ,что также опровергает нормальное распределение.
